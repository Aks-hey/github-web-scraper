# %% [markdown]
# # GitHub Topics Repository Scraper

# %% [markdown]
# ### Project Outline:
#
#
# - We're going to scrape https://github.com/topics
# - We'll get a list of topics. For each topic, we'll get topic title,
# topic page URL and topic description
# - For each topic, we'll get the top 25 repositories in the topic from the topic page
# - For each repository, we'll grab the repo name, username, stars and repo URL
# - For each topic we'll create a CSV file in the following format:
# ```
# Repo_Name,Username,Stars,Repo_URL
# three.js,mrdoob,10100,https://github.com/mrdoob/three.js
# libgdx,libgdx,23000,https://github.com/libgdx/libgdx
#
# ```

# %% [markdown]
# ### Scraping the list of topics from Github
#
# - Setting up the environment by importing necessary libraries (BeautifulSoup, requests, pandas, os)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os

# %% [markdown]
# ### Send an HTTP Request:
#    - Use the requests library to fetch the content of the GitHub Topics page.

# %%
topics_url = 'https://github.com/topics'
response = requests.get(topics_url)
if response.status_code != 200:
    raise Exception(f"Failed to load page {topics_url}")

# %% [markdown]
# ### Parse the HTML Content:
#    - Use BeautifulSoup to parse the HTML content of the page. This allows you to navigate and search the HTML structure easily.

# %%
doc = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Extracting Topic Information:
#    - Find the HTML elements containing the topic information. Typically, each topic is enclosed in a <div> tag with specific classes.

# %%
topics = doc.find_all('div', class_="py-4 border-bottom d-flex flex-justify-between")

# %% [markdown]
# #### In the class `"py-4 border-bottom d-flex flex-justify-between"`  we've topic_name, topic_description and topic_url
#
# ![](https://i.imgur.com/iMiIvAc.png)

# %% [markdown]
# #### The Function `scrape_topics()`  iterates over all the existing topics and gets the topic info and convert into DataFrame

# %%
def scrape_topics(): 
    
    # URL to append with the url which we parse from the 'href'      
    base_url = 'https://github.com/'
    
    # Topics dictionary to save the repository details
    
    topics_dict = {
        'title': [],
        'description': [],
        'url': []
    }
    
    # Iterating through every topic(repository) to get topic_name, topic_description, topic_url
    
    for topic in topics:
        topic_name = topic.find('p', class_='f3 lh-condensed mb-0 mt-1 Link--primary').text.strip()
        topic_description = topic.find('p', class_='f5 color-fg-muted mb-0 mt-1').text.strip()
        topic_link = topic.find('a', class_='no-underline flex-1 d-flex flex-column')
        topic_url = topic_link['href']
        topics_dict['title'].append(topic_name)
        topics_dict['description'].append(topic_description)
        topics_dict['url'].append(base_url + topic_url)
        
    # Converting the dictionary into a DataFrame using pandas
    
    return pd.DataFrame(topics_dict)

# %%
scrape_topics() # Here's the list of topics with title, description and url from `https://github.com/topics`
# Out:
#                      title                                        description  \
# 0                       3D  3D refers to the use of three-dimensional grap...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source platform for buildin...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10           Awesome Lists  An awesome list is a list of awesome things cu...
# 11     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 12                   Azure  Azure is a cloud computing service created by ...
# 13                   Babel  Babel is a compiler for writing next generatio...
# 14                    Bash  Bash is a shell and command language interpret...
# 15                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 16               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 17                     Bot  A bot is an application that runs automated ta...
# 18                       C  C is a general purpose programming language th...
# 19                  Chrome  Chrome is a web browser from the tech company ...
# 20        Chrome extension  Chrome extensions enable users to customize th...
# 21  Command-line interface  A CLI, or command-line interface, is a console...
# 22                 Clojure  Clojure is a dynamic, general-purpose programm...
# 23            Code quality  Automate your code review with style, quality,...
# 24             Code review  Ensure your code meets quality standards and s...
# 25                Compiler  Compilers are software that translate higher-l...
# 26  Continuous integration  Automatically build and test your code as you ...
# 27                     C++  C++ is a general purpose and object-oriented p...
# 28          Cryptocurrency  A cryptocurrency is a digital currency that us...
# 29                 Crystal  Crystal is a self-hosted, general purpose prog...
#
#                                                   url
# 0                       https://github.com//topics/3d
# 1                     https://github.com//topics/ajax
# 2                https://github.com//topics/algorithm
# 3                    https://github.com//topics/amphp
# 4                  https://github.com//topics/android
# 5                  https://github.com//topics/angular
# 6                  https://github.com//topics/ansible
# 7                      https://github.com//topics/api
# 8                  https://github.com//topics/arduino
# 9                   https://github.com//topics/aspnet
# 10                 https://github.com//topics/awesome
# 11                     https://github.com//topics/aws
# 12                   https://github.com//topics/azure
# 13                   https://github.com//topics/babel
# 14                    https://github.com//topics/bash
# 15                 https://github.com//topics/bitcoin
# 16               https://github.com//topics/bootstrap
# 17                     https://github.com//topics/bot
# 18                       https://github.com//topics/c
# 19                  https://github.com//topics/chrome
# 20        https://github.com//topics/chrome-extension
# 21                     https://github.com//topics/cli
# 22                 https://github.com//topics/clojure
# 23            https://github.com//topics/code-quality
# 24             https://github.com//topics/code-review
# 25                https://github.com//topics/compiler
# 26  https://github.com//topics/continuous-integration
# 27                     https://github.com//topics/cpp
# 28          https://github.com//topics/cryptocurrency
# 29                 https://github.com//topics/crystal

# %% [markdown]
# #### The Function `parse_stars_count()` is used to convert the repo_ratings from string into real numbers

# %%
def parse_stars_count(stars_str):
    if stars_str[-1] == 'k':
        return int(float(stars_str[:-1]) * 1000)
    elif stars_str[-1] == 'M':
        return int(float(stars_str[:-1]) * 1000000)
    else:
        return int(stars_str)

# %% [markdown]
# #### The Function `fetch_topic_page()` downloads and parses the topic page.

# %%
def fetch_topic_page(topic_url):
    # Download the page
    response = requests.get(topic_url)
    
    # Check successful response
    if response.status_code != 200:
        raise Exception(f"Failed to load page {topic_url}")
        
    # Parse using BeautifulSoup
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    
    return topic_doc

# %% [markdown]
# #### The class `"d-flex flex-justify-between flex-items-start flex-wrap gap-2 my-3"` contains repo_name, repo_user_name, repo_rating
# ![](https://i.imgur.com/2kUfMrP.png)

# %% [markdown]
# #### The Function `extract_repo_info()` extracts repository information from the parsed HTML.

# %%
def extract_repo_info(topic_doc):
    # Create the dictionary with repository details
    repos_dict = {
        'repo_name': [],
        'user_name': [],
        'repo_rating': [],
        'repo_url': [] 
    }
    
    base_url = 'https://github.com/'

    # Get repo_name, user_name, star_count, repo_url from 'div' tag
    repository = topic_doc.find_all('div', class_='d-flex flex-justify-between flex-items-start flex-wrap gap-2 my-3')
    
    for repo in repository:
        cleaned_repo = repo.text.strip().replace('\n', '').split()
        repos_dict['repo_name'].append(cleaned_repo[0])
        repos_dict['user_name'].append(cleaned_repo[2])    
        repos_dict['repo_rating'].append(parse_stars_count(cleaned_repo[-1]))
        full_url = base_url + cleaned_repo[0] + '/' + cleaned_repo[2]
        repos_dict['repo_url'].append(full_url)
    
    return pd.DataFrame(repos_dict)

# %%
url = 'https://github.com//topics/3d' # url to display the output of a particular repository
type_doc = fetch_topic_page(url)
df = extract_repo_info(type_doc)
df
# Out:
#              repo_name                      user_name  repo_rating  \
# 0               mrdoob                       three.js       101000
# 1               pmndrs              react-three-fiber        26800
# 2               libgdx                         libgdx        23000
# 3            BabylonJS                     Babylon.js        22800
# 4                ssloy                   tinyrenderer        19900
# 5              FreeCAD                        FreeCAD        18400
# 6              lettier  3d-game-shaders-for-beginners        17500
# 7             aframevr                         aframe        16500
# 8             CesiumGS                         cesium        12500
# 9              blender                        blender        12300
# 10            MonoGame                       MonoGame        11100
# 11              mapbox                   mapbox-gl-js        10900
# 12             isl-org                         Open3D        10900
# 13           metafizzy                           zdog        10300
# 14         timzhang642            3D-Machine-Learning         9600
# 15  nerfstudio-project                     nerfstudio         9000
# 16                4ian                       GDevelop         8100
# 17        a1studmuffin             SpaceshipGenerator         7600
# 18         FyroxEngine                          Fyrox         7500
# 19             domlysz                     BlenderGIS         7500
#
#                                              repo_url
# 0                  https://github.com/mrdoob/three.js
# 1         https://github.com/pmndrs/react-three-fiber
# 2                    https://github.com/libgdx/libgdx
# 3             https://github.com/BabylonJS/Babylon.js
# 4               https://github.com/ssloy/tinyrenderer
# 5                  https://github.com/FreeCAD/FreeCAD
# 6   https://github.com/lettier/3d-game-shaders-for...
# 7                  https://github.com/aframevr/aframe
# 8                  https://github.com/CesiumGS/cesium
# 9                  https://github.com/blender/blender
# 10               https://github.com/MonoGame/MonoGame
# 11             https://github.com/mapbox/mapbox-gl-js
# 12                  https://github.com/isl-org/Open3D
# 13                  https://github.com/metafizzy/zdog
# 14  https://github.com/timzhang642/3D-Machine-Lear...
# 15   https://github.com/nerfstudio-project/nerfstudio
# 16                   https://github.com/4ian/GDevelop
# 17  https://github.com/a1studmuffin/SpaceshipGener...
# 18               https://github.com/FyroxEngine/Fyrox
# 19              https://github.com/domlysz/BlenderGIS

# %% [markdown]
# #### The Function `scrape_topic_repos()`:
# - It calls `scrape_topics` function to get the topic information
# - It also calls `fetch_topic_page()` and `extract_repo_info()` function to get the repo response and information
# - We've created a CSV file for scraped repos from topics page

# %%
def scrape_topic_repos():
    
    topics_df = scrape_topics()
    
    # Create a new directory for CSV files
    
    directory = "GitHub_Topic_Repos"
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # Iterate over rows using itertuples() and process each topic    
    
    for row in topics_df.itertuples(index=False):
        topic_name = row.title
        topic_url = row.url
        print(f"Scraping repositories for topic: {topic_name} from URL: {topic_url}")
        
        # Calling fetch_topic_page and extract_repo_info to iterate over every topic_url and get repo_name, repo_user_name, repo_rating, repo_url
        
        topic_docs = fetch_topic_page(topic_url)
        df = extract_repo_info(topic_docs)
        
        # Saving the extracted info into a .csv file
        
        file_name = f"{directory}/{topic_name}.csv"
        df.to_csv(file_name, index=False)
        print(f"Data for topic '{topic_name}' has been saved to {file_name}")

# %% [markdown]
# #### Let's run it to scrape the top repos for all the topics on the first page of https://github.com/topics

# %%
scrape_topic_repos() # list of repo files parsed
# Out:
# Scraping repositories for topic: 3D from URL: https://github.com//topics/3d
# Data for topic '3D' has been saved to GitHub_Topic_Repos/3D.csv
# Scraping repositories for topic: Ajax from URL: https://github.com//topics/ajax
# Data for topic 'Ajax' has been saved to GitHub_Topic_Repos/Ajax.csv
# Scraping repositories for topic: Algorithm from URL: https://github.com//topics/algorithm
# Data for topic 'Algorithm' has been saved to GitHub_Topic_Repos/Algorithm.csv
# Scraping repositories for topic: Amp from URL: https://github.com//topics/amphp
# Data for topic 'Amp' has been saved to GitHub_Topic_Repos/Amp.csv
# Scraping repositories for topic: Android from URL: https://github.com//topics/android
# Data for topic 'Android' has been saved to GitHub_Topic_Repos/Android.csv
# Scraping repositories for topic: Angular from URL: https://github.com//topics/angular
# Data for topic 'Angular' has been saved to GitHub_Topic_Repos/Angular.csv
# Scraping repositories for topic: Ansible from URL: https://github.com//topics/ansible
# Data for topic 'Ansible' has been saved to GitHub_Topic_Repos/Ansible.csv
# Scraping repositories for topic: API from URL: https://github.com//topics/api
# Data for topic 'API' has been saved to GitHub_Topic_Repos/API.csv
# Scraping repositories for topic: Arduino from URL: https://github.com//topics/arduino
# Data for topic 'Arduino' has been saved to GitHub_Topic_Repos/Arduino.csv
# Scraping repositories for topic: ASP.NET from URL: https://github.com//topics/aspnet
# Data for topic 'ASP.NET' has been saved to GitHub_Topic_Repos/ASP.NET.csv
# Scraping repositories for topic: Awesome Lists from URL: https://github.com//topics/awesome
# Data for topic 'Awesome Lists' has been saved to GitHub_Topic_Repos/Awesome Lists.csv
# Scraping repositories for topic: Amazon Web Services from URL: https://github.com//topics/aws
# Data for topic 'Amazon Web Services' has been saved to GitHub_Topic_Repos/Amazon Web Services.csv
# Scraping repositories for topic: Azure from URL: https://github.com//topics/azure
# Data for topic 'Azure' has been saved to GitHub_Topic_Repos/Azure.csv
# Scraping repositories for topic: Babel from URL: https://github.com//topics/babel
# Data for topic 'Babel' has been saved to GitHub_Topic_Repos/Babel.csv
# Scraping repositories for topic: Bash from URL: https://github.com//topics/bash
# Data for topic 'Bash' has been saved to GitHub_Topic_Repos/Bash.csv
# Scraping repositories for topic: Bitcoin from URL: https://github.com//topics/bitcoin
# Data for topic 'Bitcoin' has been saved to GitHub_Topic_Repos/Bitcoin.csv
# Scraping repositories for topic: Bootstrap from URL: https://github.com//topics/bootstrap
# Data for topic 'Bootstrap' has been saved to GitHub_Topic_Repos/Bootstrap.csv
# Scraping repositories for topic: Bot from URL: https://github.com//topics/bot
# Data for topic 'Bot' has been saved to GitHub_Topic_Repos/Bot.csv
# Scraping repositories for topic: C from URL: https://github.com//topics/c
# Data for topic 'C' has been saved to GitHub_Topic_Repos/C.csv
# Scraping repositories for topic: Chrome from URL: https://github.com//topics/chrome
# Data for topic 'Chrome' has been saved to GitHub_Topic_Repos/Chrome.csv
# Scraping repositories for topic: Chrome extension from URL: https://github.com//topics/chrome-extension
# Data for topic 'Chrome extension' has been saved to GitHub_Topic_Repos/Chrome extension.csv
# Scraping repositories for topic: Command-line interface from URL: https://github.com//topics/cli
# Data for topic 'Command-line interface' has been saved to GitHub_Topic_Repos/Command-line interface.csv
# Scraping repositories for topic: Clojure from URL: https://github.com//topics/clojure
# Data for topic 'Clojure' has been saved to GitHub_Topic_Repos/Clojure.csv
# Scraping repositories for topic: Code quality from URL: https://github.com//topics/code-quality
# Data for topic 'Code quality' has been saved to GitHub_Topic_Repos/Code quality.csv
# Scraping repositories for topic: Code review from URL: https://github.com//topics/code-review
# Data for topic 'Code review' has been saved to GitHub_Topic_Repos/Code review.csv
# Scraping repositories for topic: Compiler from URL: https://github.com//topics/compiler
# Data for topic 'Compiler' has been saved to GitHub_Topic_Repos/Compiler.csv
# Scraping repositories for topic: Continuous integration from URL: https://github.com//topics/continuous-integration
# Data for topic 'Continuous integration' has been saved to GitHub_Topic_Repos/Continuous integration.csv
# Scraping repositories for topic: C++ from URL: https://github.com//topics/cpp
# Data for topic 'C++' has been saved to GitHub_Topic_Repos/C++.csv
# Scraping repositories for topic: Cryptocurrency from URL: https://github.com//topics/cryptocurrency
# Data for topic 'Cryptocurrency' has been saved to GitHub_Topic_Repos/Cryptocurrency.csv
# Scraping repositories for topic: Crystal from URL: https://github.com//topics/crystal
# Data for topic 'Crystal' has been saved to GitHub_Topic_Repos/Crystal.csv

# %% [markdown]
# ![](https://i.imgur.com/fo0Orgt.png)

# %% [markdown]
# #### We can check if the CSVs are created properly using pandas

# %%
# read and display one of CSV file

pd.read_csv('GitHub_Topic_Repos/C.csv')
# Out:
#         repo_name                user_name  repo_rating  \
# 0      Genymobile                   scrcpy       106000
# 1          neovim                   neovim        80400
# 2      obsproject               obs-studio        57800
# 3         fffaraz              awesome-cpp        57400
# 4             git                      git        51200
# 5          FFmpeg                   FFmpeg        44000
# 6   serhii-londar  open-source-mac-os-apps        40600
# 7             vim                      vim        35700
# 8            curl                     curl        34900
# 9          huihut                interview        33900
# 10     mpv-player                      mpv        26900
# 11         ggreer      the_silver_searcher        25900
# 12          ossrs                      srs        24900
# 13     kovidgoyal                    kitty        23000
# 14         google              flatbuffers        22600
# 15      microsoft                    vcpkg        22400
# 16           ruby                     ruby        21800
# 17        raysan5                   raylib        20700
# 18        hashcat                  hashcat        20500
# 19      radareorg                  radare2        20100
#
#                                              repo_url
# 0                https://github.com/Genymobile/scrcpy
# 1                    https://github.com/neovim/neovim
# 2            https://github.com/obsproject/obs-studio
# 3              https://github.com/fffaraz/awesome-cpp
# 4                          https://github.com/git/git
# 5                    https://github.com/FFmpeg/FFmpeg
# 6   https://github.com/serhii-londar/open-source-m...
# 7                          https://github.com/vim/vim
# 8                        https://github.com/curl/curl
# 9                 https://github.com/huihut/interview
# 10                  https://github.com/mpv-player/mpv
# 11      https://github.com/ggreer/the_silver_searcher
# 12                       https://github.com/ossrs/srs
# 13                https://github.com/kovidgoyal/kitty
# 14              https://github.com/google/flatbuffers
# 15                 https://github.com/microsoft/vcpkg
# 16                       https://github.com/ruby/ruby
# 17                  https://github.com/raysan5/raylib
# 18                 https://github.com/hashcat/hashcat
# 19               https://github.com/radareorg/radare2

# %% [markdown]
# ## Summary and Future Work:
#
# - Scrape the GitHub Topics page and get a list of topics
# - Extract each topic's title, description, and URL
# - For each topic, fetch the top repositories.
# - Extract repository details including name, username, star count, and URL.
# - Save the extracted repository data into CSV files, with each file named after the respective topic.
#
# ## References:
#
# - https://imgur.com/ - To get the links of the screenshot
# - https://pandas.pydata.org/docs/index.html - pandas documentation
# - https://www.crummy.com/software/BeautifulSoup/bs4/doc/ - BeautifulSoup documentation
#
# ## Future Work:
#
# - To get the list of more topics we can have end_url as: `"/go/?page=2"` we need to join the base_url and topic_url and end_url
# - So that we can parse more topics
# - The same can be done for the repos too end_url as: `"/?page=2"`
